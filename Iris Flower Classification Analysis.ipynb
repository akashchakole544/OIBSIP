# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %% [raw]
# We can see that dataframe contains 150 rows and 6 columns

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_c832f_row0_col0, #T_c832f_row0_col1, #T_c832f_row0_col2, #T_c832f_row0_col3, #T_c832f_row0_col4, #T_c832f_row7_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c832f_row1_col0, #T_c832f_row5_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_c832f_row1_col1, #T_c832f_row5_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_c832f_row1_col2, #T_c832f_row1_col3, #T_c832f_row4_col2, #T_c832f_row5_col2, #T_c832f_row6_col2, #T_c832f_row7_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c832f_row1_col4, #T_c832f_row2_col3, #T_c832f_row2_col4, #T_c832f_row4_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_c832f_row2_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_c832f_row2_col1, #T_c832f_row2_col2, #T_c832f_row3_col0, #T_c832f_row3_col3, #T_c832f_row3_col4, #T_c832f_row4_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# ...

# %%
#as per shape and describe,we observed that There is no null values in the dataset
# there is no much difference in the max and 75% 
#here we can also see mean,median & standard deviation.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [raw]
# We can see that there is only one categorical column while 5 are numerical columns with not null values

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#check for null values
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [raw]
# We can see that no column has any missing value

# %%
df.drop_duplicates(subset='Species')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 100  101            6.3           3.3            6.0           2.5
#
#              Species
# 0        Iris-setosa
# 50   Iris-versicolor
# 100   Iris-virginica

# %%
df.value_counts('Species')
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
ax = sns.countplot(x='Species',data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [raw]
# here, All the species contains equal amount of rows

# %%
sns.countplot(x='SepalLengthCm',data=df.head(20))
plt.show()

# %% [raw]
# here is count of flowers iris for its sepalLength

# %%
ax = sns.histplot(x='SepalLengthCm',data=df,hue='Species')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.histplot(x='SepalWidthCm',data=df,hue='Species')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.histplot(x='PetalLengthCm',data=df,hue='Species')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.histplot(x='PetalWidthCm',data=df,hue='Species')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=df,hue='Species',palette="deep")
plt.show()

# %% [raw]
# we can see that iris setosa has smaller petallength and smaller sepallength
# similarly iris versicolor has middle range of both petallength and sepallength
# Iris virginica has higher petallength and sepallength

# %%
sns.lmplot(x='SepalLengthCm',y='SepalWidthCm',data=df,hue='Species')
plt.show()

# %% [raw]
# we can see that lmplot show positive growth with respect to sepalwidth and sepallength in all the species --iris setosa,--iris versicolor, --iris virginica

# %%
sns.lineplot(x='PetalLengthCm',y='PetalWidthCm',hue='Species',data=df)
plt.show()

# %%
#we can see that iris setosa has values of petalwidth & petallength between 1 to 2
#iris versicolor has values between 3 to 5 for petalwidth & petallength
#iris-virginica has betweenn 4 to 7 for petalwidth & petallength

# %%
sns.kdeplot(x='PetalWidthCm',y='SepalWidthCm',hue='Species',data=df,fill=True,)
plt.show()

# %%
sns.lineplot(
    data=df,
    x="SepalLengthCm", y="SepalWidthCm",hue='Species'
)
plt.show()

# %%
import seaborn as sns

# %%
sns.lmplot(
    data=df.head(20),
    x="PetalLengthCm", y="PetalWidthCm",hue='Species'
)

# %% [raw]
# we can see that there is positve growth with respect to Petallength and petalwidth at all species

# %%
sns.kdeplot(x='SepalLengthCm',data=df,fill=True,y='PetalLengthCm',hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %% [raw]
# An ECDF represents the proportion or count of observations falling below each unique value in a dataset. Compared to a histogram or density plot, it has the advantage that each observation is visualized directly, meaning that there are no binning or smoothing parameters that need to be adjusted.

# %%
df.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
sns.ecdfplot(data=df, x="PetalLengthCm",hue='Species')
plt.show()

# %% [markdown]
# ### Correlation

# %%
df.corr(method='pearson')
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_26600\1928163937.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sns.heatmap(df.corr(method='pearson').drop(['Id'],axis=1).drop(['Id'],axis=0),annot=True);
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_26600\1918569409.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method='pearson').drop(['Id'],axis=1).drop(['Id'],axis=0),annot=True);

# %% [raw]
# Here we can see that PetalLength and PetalWidth has maximum correlation,

# %% [markdown]
# ### BoxPlot

# %%
import seaborn as sns

# %%
sns.boxplot(x='SepalWidthCm',data=df)
plt.show()

# %% [raw]
# value above 4 and below 2 are outliers, Values are more between 2.5 to 3.5
